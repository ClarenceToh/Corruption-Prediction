# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import ExtraTreesClassifier

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-eb586c0f-5e7c-45d6-a334-bd520da6396a" name="files[]" multiple disabled />
#      <output id="result-eb586c0f-5e7c-45d6-a334-bd520da6396a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving datav3.csv to datav3 (3).csv

# %%
data = pd.read_csv("datav3.csv")
data.shape
# Out:
# (179, 1084)

# %%
#if CPI vals are missing, drop the country
data = data[pd.notnull(data['CPI'])]
data.shape
# Out:
# (175, 1084)

# %%
def bins (y):
    if y <= 20:
        final = 0
    elif y > 21 and y <= 40:
        final = 1
    elif y > 41 and y <= 60:
        final = 2
    elif y > 61 and y <= 80:
        final = 3
    else:
        final = 4
    return final
data["CPI class"] = data["CPI"].apply(lambda x: bins(x))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]

# %%
#divide data into bins
bin0 = data[data["CPI class"] == 0]
print(bin0.shape)
bin1 = data[data["CPI class"] == 1]
print(bin1.shape)
bin2 = data[data["CPI class"] == 2]
print(bin2.shape)
bin3 = data[data["CPI class"] == 3]
print(bin3.shape)
bin4 = data[data["CPI class"] == 4]
print(bin4.shape)
# Out:
# (18, 1085)
# (77, 1085)
# (40, 1085)
# (18, 1085)
# (22, 1085)

# %%
#drop cols 
#do a 70% rate
#replace with median for that bin
#data.shape
f = []
bins = [bin0,bin1,bin2,bin3,bin4]
for i in bins:
  for j in features:
    #if 70% of bin.x vals.features is missing
      #store that feature in an array

u = np.arraya(f)
print(unique(u))
# Out:
# (179, 1085)

# %%
import seaborn as sns
sns.distplot(data['CPI'])

# %%
from sklearn.preprocessing import MinMaxScaler

features = list(data.columns) 
features.remove('CPI')
features.remove('Country')
features.remove('CPI class')

x = data.loc[:, features].values
y = data.CPI

countries = data.Country

x = pd.DataFrame(x, columns=features)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/data.py:355: RuntimeWarning: All-NaN slice encountered
#   data_min = np.nanmin(X, axis=0)
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/data.py:356: RuntimeWarning: All-NaN slice encountered
#   data_max = np.nanmax(X, axis=0)

# %%
data
# Out:
#      Access to electricity (% of population)  ...  CPI class
# 0                                  65.440483  ...          0
# 1                                 100.000000  ...          1
# 2                                 100.000000  ...          1
# 3                                 100.000000  ...          0
# 4                                 100.000000  ...          1
# ..                                       ...  ...        ...
# 174                               100.000000  ...          0
# 175                               100.000000  ...          1
# 176                               100.000000  ...          0
# 177                               100.000000  ...          1
# 178                                84.137138  ...          1
#
# [179 rows x 1085 columns]

# %%
bin0 =
